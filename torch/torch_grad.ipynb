# %%
import torch

# %%
X = torch.tensor([1, 2, 3,4,5], dtype=torch.float32)
Y = torch.tensor([2, 4, 6,8,10], dtype=torch.float32)

w = torch.tensor(0.0, dtype=torch.float32, requires_grad=True)

# %%
def forward(x):
    return x*w

# %%
def compute_loss(y_predicted, y):
    return ((y_predicted - y)**2).mean()

# %%
print(f"Prediction before training: f(5)= {forward(6):.3f}")
# Out:
# Prediction before training: f(5)= 0.000

# %%
learning_rate = 0.01
num_epochs = 100

# %%
for epoch in range(num_epochs):
    y_pred = forward(X)
    l = compute_loss(y_pred, Y)
    
    l.backward() # dl/dw

    with torch.no_grad():
        w-= learning_rate*w.grad

    #zero grad
    w.grad.zero_()

    if epoch % 1 == 0:
        print(f'epoch {epoch+1}: w = {w:.3f}, loss = {l:.8f}')


print(f'Prediction after training: f(5) = {forward(6):.3f}')
# Out:
# epoch 1: w = 0.440, loss = 44.00000000
# epoch 2: w = 0.783, loss = 26.76960182
# epoch 3: w = 1.051, loss = 16.28662491
# epoch 4: w = 1.260, loss = 9.90878487
# epoch 5: w = 1.423, loss = 6.02850342
# epoch 6: w = 1.550, loss = 3.66774178
# epoch 7: w = 1.649, loss = 2.23145342
# epoch 8: w = 1.726, loss = 1.35761607
# epoch 9: w = 1.786, loss = 0.82597363
# epoch 10: w = 1.833, loss = 0.50252259
# epoch 11: w = 1.870, loss = 0.30573449
# epoch 12: w = 1.899, loss = 0.18600900
# epoch 13: w = 1.921, loss = 0.11316784
# epoch 14: w = 1.938, loss = 0.06885126
# epoch 15: w = 1.952, loss = 0.04188926
# epoch 16: w = 1.962, loss = 0.02548538
# epoch 17: w = 1.971, loss = 0.01550541
# epoch 18: w = 1.977, loss = 0.00943349
# epoch 19: w = 1.982, loss = 0.00573931
# epoch 20: w = 1.986, loss = 0.00349178
# epoch 21: w = 1.989, loss = 0.00212438
# epoch 22: w = 1.992, loss = 0.00129247
# epoch 23: w = 1.993, loss = 0.00078634
# epoch 24: w = 1.995, loss = 0.00047842
# epoch 25: w = 1.996, loss = 0.00029106
# epoch 26: w = 1.997, loss = 0.00017709
# epoch 27: w = 1.998, loss = 0.00010774
# epoch 28: w = 1.998, loss = 0.00006555
# epoch 29: w = 1.999, loss = 0.00003988
# epoch 30: w = 1.999, loss = 0.00002426
# epoch 31: w = 1.999, loss = 0.00001476
# epoch 32: w = 1.999, loss = 0.00000898
# epoch 33: w = 1.999, loss = 0.00000546
# epoch 34: w = 2.000, loss = 0.00000332
# epoch 35: w = 2.000, loss = 0.00000202
# epoch 36: w = 2.000, loss = 0.00000123
# epoch 37: w = 2.000, loss = 0.00000075
# epoch 38: w = 2.000, loss = 0.00000046
# epoch 39: w = 2.000, loss = 0.00000028
# epoch 40: w = 2.000, loss = 0.00000017
# epoch 41: w = 2.000, loss = 0.00000010
# epoch 42: w = 2.000, loss = 0.00000006
# epoch 43: w = 2.000, loss = 0.00000004
# epoch 44: w = 2.000, loss = 0.00000002
# epoch 45: w = 2.000, loss = 0.00000001
# epoch 46: w = 2.000, loss = 0.00000001
# epoch 47: w = 2.000, loss = 0.00000001
# epoch 48: w = 2.000, loss = 0.00000000
# epoch 49: w = 2.000, loss = 0.00000000
# epoch 50: w = 2.000, loss = 0.00000000
# epoch 51: w = 2.000, loss = 0.00000000
# epoch 52: w = 2.000, loss = 0.00000000
# epoch 53: w = 2.000, loss = 0.00000000
# epoch 54: w = 2.000, loss = 0.00000000
# epoch 55: w = 2.000, loss = 0.00000000
# epoch 56: w = 2.000, loss = 0.00000000
# epoch 57: w = 2.000, loss = 0.00000000
# epoch 58: w = 2.000, loss = 0.00000000
# epoch 59: w = 2.000, loss = 0.00000000
# epoch 60: w = 2.000, loss = 0.00000000
# epoch 61: w = 2.000, loss = 0.00000000
# epoch 62: w = 2.000, loss = 0.00000000
# epoch 63: w = 2.000, loss = 0.00000000
# epoch 64: w = 2.000, loss = 0.00000000
# epoch 65: w = 2.000, loss = 0.00000000
# epoch 66: w = 2.000, loss = 0.00000000
# epoch 67: w = 2.000, loss = 0.00000000
# epoch 68: w = 2.000, loss = 0.00000000
# epoch 69: w = 2.000, loss = 0.00000000
# epoch 70: w = 2.000, loss = 0.00000000
# epoch 71: w = 2.000, loss = 0.00000000
# epoch 72: w = 2.000, loss = 0.00000000
# epoch 73: w = 2.000, loss = 0.00000000
# epoch 74: w = 2.000, loss = 0.00000000
# epoch 75: w = 2.000, loss = 0.00000000
# epoch 76: w = 2.000, loss = 0.00000000
# epoch 77: w = 2.000, loss = 0.00000000
# epoch 78: w = 2.000, loss = 0.00000000
# epoch 79: w = 2.000, loss = 0.00000000
# epoch 80: w = 2.000, loss = 0.00000000
# epoch 81: w = 2.000, loss = 0.00000000
# epoch 82: w = 2.000, loss = 0.00000000
# epoch 83: w = 2.000, loss = 0.00000000
# epoch 84: w = 2.000, loss = 0.00000000
# epoch 85: w = 2.000, loss = 0.00000000
# epoch 86: w = 2.000, loss = 0.00000000
# epoch 87: w = 2.000, loss = 0.00000000
# epoch 88: w = 2.000, loss = 0.00000000
# epoch 89: w = 2.000, loss = 0.00000000
# epoch 90: w = 2.000, loss = 0.00000000
# epoch 91: w = 2.000, loss = 0.00000000
# epoch 92: w = 2.000, loss = 0.00000000
# epoch 93: w = 2.000, loss = 0.00000000
# epoch 94: w = 2.000, loss = 0.00000000
# epoch 95: w = 2.000, loss = 0.00000000
# epoch 96: w = 2.000, loss = 0.00000000
# epoch 97: w = 2.000, loss = 0.00000000
# epoch 98: w = 2.000, loss = 0.00000000
# epoch 99: w = 2.000, loss = 0.00000000
# epoch 100: w = 2.000, loss = 0.00000000
# Prediction after training: f(5) = 12.000
